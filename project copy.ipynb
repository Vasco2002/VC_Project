# %%
import torch
import torchvision

import torchinfo

import matplotlib.pyplot as plt
import numpy as np
import time

# importing a module with utilities for displaying stats and data
import sys
sys.path.insert(1, 'util')
import vcpi_util

# %% [markdown]
# ### Init device

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else 'cpu')
print(torch.__version__)
print(device)
# Out:
# 2.2.1+cu121
# cuda:0

# %% [markdown]
# ### Settings

# %%
BATCH_SIZE = 64
EPOCKS = 20
IMG_SIZE = 32
EPOCHS = 1000

PATH_TRAINING_SET = "data/train_images/GTSRB/Final_Training/Images"
PATH_TEST_SET = "data/test_images"

# %% [markdown]
# ### Model Building Aux

# %%
def train(model, data_loader, epochs, loss_fn, optimizer):

    # sets the model in training mode.
    # although our model does not have layers which behave differently during training and evaluation
    # this is a good practice as the models architecture may change in the future
    model.train()

    history = {}
    history['accuracy'] = []
    history['loss'] = []

    for epoch in range(epochs):  # loop over the dataset multiple times

        start_time = time.time() 
        correct = 0
        running_loss = 0.0
        for i, (inputs, targets) in enumerate(data_loader, 0):
            
            # send data to device, hopefully the GPU
            inputs = inputs.to(device)
            targets = targets.to(device)

            # forward pass, compute the output of the model for the current batch
            outputs = model(inputs)


            _, predicted = torch.max(outputs, 1)

            #compute the loss between the model's outputs and the labels, or targets.
            loss = loss_fn(outputs, targets)
            
            # zero the parameter gradients
            # this function must be called before calling "backward" on the losses, otherwise the gradients get accumulated with previous batches.
            optimizer.zero_grad()

            # perform backpropagation
            loss.backward()
            #update the model's parameters
            optimizer.step()

            running_loss += loss
            correct += (predicted == targets).sum()

        accuracy = 100 * correct / len(train_set)
        stop_time = time.time()
        print(f'Epoch: {epoch:03d}; Accuracy = {accuracy:0.4f}; Elapsed time: {(stop_time - start_time):0.4f}')
        history['accuracy'].append(accuracy.cpu().numpy())
        history['loss'].append(running_loss.cpu().detach().numpy())
        
    print('Finished Training')

    return history

def train2(model, train_loader, val_loader, epochs, loss_fn, optimizer,
           scheduler, early_stopper, save_prefix = 'model'):

    history = {}
    history['accuracy'] = []
    history['val_acc'] = []
    history['val_loss'] = []
    history['loss'] = []
    best_val_loss = np.inf

    for epoch in range(epochs):  # loop over the dataset multiple times

        model.train()
        start_time = time.time() 
        correct = 0
        running_loss = 0.0
        for i, (inputs, targets) in enumerate(train_loader, 0):
            
            inputs = inputs.to(device)
            targets = targets.to(device)

            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)

            loss = loss_fn(outputs, targets)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss
            correct += (predicted == targets).sum()

        model.eval()
        v_correct = 0
        val_loss = 0.0
        with torch.no_grad():
            for i,t in val_loader:
                i = i.to(device)
                t = t.to(device)
                o = model(i)
                _,p = torch.max(o,1)
                
                #with torch.no_grad():
                val_loss += loss_fn(o, t)

                v_correct += (p == t).sum()

        old_lr = optimizer.param_groups[0]['lr']
        scheduler.step(val_loss)
        new_lr = optimizer.param_groups[0]['lr']
        
        if old_lr != new_lr:
            print('==> Learning rate updated: ', old_lr, ' -> ', new_lr)

        epoch_loss = running_loss / len(train_loader.dataset)
        accuracy = 100 * correct / len(train_loader.dataset)
        v_accuracy = 100 * v_correct / len(val_loader.dataset)
        val_loss = val_loss / len(val_loader.dataset)
        stop_time = time.time()
        print(f'Epoch: {epoch:03d}; Loss: {epoch_loss:0.6f}; Accuracy: {accuracy:0.4f}; Val Loss: {val_loss:0.6f}; Val Acc: {v_accuracy:0.4f}; Elapsed time: {(stop_time - start_time):0.4f}')
        history['accuracy'].append(accuracy.cpu().numpy())
        history['val_acc'].append(v_accuracy.cpu().numpy())
        history['val_loss'].append(val_loss.cpu().detach().numpy())
        history['loss'].append(epoch_loss.cpu().detach().numpy())
 
        ###### Saving ######
        if val_loss < best_val_loss:
           
            torch.save({
                'epoch': epoch,
                'model':model.state_dict(),
                'optimizer': optimizer.state_dict(),
                'scheduler': scheduler.state_dict()
                },
                f'models/{save_prefix}.pt')

        if early_stopper(val_loss):
            print('Early stopping!')
            break
        
    print('Finished Training')

    return(history)


def evaluate(model, data_loader):

    # sets the model in evaluation mode.
    # although our model does not have layers which behave differently during training and evaluation
    # this is a good practice as the models architecture may change in the future
    model.eval()

    correct = 0
    
    for i, (images, targets) in enumerate(data_loader):
         
        # forward pass, compute the output of the model for the current batch
        outputs = model(images.to(device))

        # "max" returns a namedtuple (values, indices) where values is the maximum 
        # value of each row of the input tensor in the given dimension dim; 
        # indices is the index location of each maximum value found (argmax).
        # the argmax effectively provides the predicted class number        
        _, preds = torch.max(outputs, dim=1)

        correct += (preds.cpu() == targets).sum()

    return (correct / len(data_loader.dataset)).item()


class Conv(torch.nn.Module):

    def __init__(self, num_classes):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(3, 16, 3)
        self.bn1 = torch.nn.BatchNorm2d(16)
        self.relu1 = torch.nn.ReLU()

        self.conv2 = torch.nn.Conv2d(16, 32, 3)
        self.bn2 = torch.nn.BatchNorm2d(32)
        self.relu2 = torch.nn.ReLU()

        self.maxpool1 = torch.nn.MaxPool2d(2)


        self.conv3 = torch.nn.Conv2d(32, 48, 3)
        self.bn3 = torch.nn.BatchNorm2d(48)
        self.relu3 = torch.nn.ReLU()

        self.conv4 = torch.nn.Conv2d(48, 48, 3)
        self.bn4 = torch.nn.BatchNorm2d(48)
        self.relu4 = torch.nn.ReLU()

        self.maxpool2 = torch.nn.MaxPool2d(2)

        self.fc1 = torch.nn.Linear(1200, num_classes)
        

    def forward(self, x):    
        
        # input = (bs, 3, 32, 32)
        x = self.conv1(x) # -> (bs, 16, 30, 30)
        x = self.bn1(x)
        x = self.relu1(x)
        x = self.conv2(x) # -> (bs, 32, 28, 28)
        x = self.bn2(x)
        x = self.relu2(x)
        x = self.maxpool1(x) # -> (bs, 32, 14, 14)
        
        x = self.conv3(x) # -> (bs, 48, 12, 12)
        x = self.bn3(x)
        x = self.relu3(x)
        x = self.conv4(x) # -> (bs, 48, 10, 10)
        x = self.bn4(x)
        x = self.relu4(x)
        x = self.maxpool2(x) # -> (bs, 48, 5, 5)
        
        x = torch.flatten(x,1) # -> (bs, 48 * 5 * 5 = 1200)
        x = self.fc1(x)        # -> (bs, num_classes)

        return(x)


class Early_Stopping():

    def __init__(self, patience = 3, min_delta = 0.00001):

        self.patience = patience 
        self.min_delta = min_delta

        self.min_delta
        self.min_val_loss = float('inf')

    def __call__(self, val_loss):

        # improvement
        if val_loss + self.min_delta < self.min_val_loss:
            self.min_val_loss = val_loss
            self.counter = 0

        # no improvement            
        else:
            self.counter += 1
            if self.counter > self.patience:
                return True
            
        return False
    


def build_confusion_matrix(model, dataset):

    preds = []
    ground_truth = []

    for images, targets in dataset:

        predictions = model(images.to(device))
        preds_sparse = [np.argmax(x) for x in predictions.cpu().detach().numpy()]
        preds.extend(preds_sparse)
        ground_truth.extend(targets.numpy())

    vcpi_util.show_confusion_matrix(ground_truth, preds, len(test_set.classes)) 

def build_confusion_matrix2(model, dataset, class_names):
    preds = []
    ground_truth = []

    for images, targets in dataset:
        predictions = model(images.to(device))
        preds_sparse = [np.argmax(x) for x in predictions.cpu().detach().numpy()]
        preds.extend(preds_sparse)
        ground_truth.extend(targets.numpy())

    num_classes = len(class_names) if class_names else len(set(ground_truth))
    vcpi_util.show_confusion_matrix(ground_truth, preds, len(test_set.classes))

# %% [markdown]
# ## Model with Transform Set 1
# ### Data Loading

# %%
from torchvision.transforms import v2


train_transform = v2.Compose([
        v2.ToImage(),
        v2.Resize((IMG_SIZE + 6, IMG_SIZE + 6)),
        v2.CenterCrop(size=(IMG_SIZE, IMG_SIZE)),
        v2.ColorJitter(contrast=(1.4, 1.4)),
        v2.ToDtype(torch.float32, scale=True),
])

test_transform = v2.Compose([
        v2.ToImage(),
        v2.Resize((IMG_SIZE + 4, IMG_SIZE + 4)),
        v2.CenterCrop(size=(IMG_SIZE, IMG_SIZE)),
        v2.ColorJitter(contrast=(1.4, 1.4)),
        v2.ToDtype(torch.float32, scale=True),
])

# %%
# No shuffle is required for the test set, also the batch size can be completely different
test_set = torchvision.datasets.ImageFolder(root=PATH_TEST_SET, transform = test_transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size = BATCH_SIZE)

train_set = torchvision.datasets.ImageFolder(root=PATH_TRAINING_SET, transform = train_transform)
train_loader = torch.utils.data.DataLoader(train_set, batch_size = BATCH_SIZE)

# %%
images, targets = next(iter(train_loader))
vcpi_util.show_images(4,8,images,targets,train_set.classes)

# %% [markdown]
# ### Model Training

# %%
model = Conv(len(train_set.classes))
model.to(device)

optimizer = torch.optim.SGD(model.parameters())
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor = 0.1, patience=3)
loss_fn = torch.nn.CrossEntropyLoss()

early_stop = Early_Stopping(9)

# %%
history = train2(
    model, train_loader, test_loader, 
    EPOCHS, loss_fn, optimizer, scheduler, early_stop, 'model_6')
# Out:
# Epoch: 000; Loss: 0.025349; Accuracy: 65.9440; Val Loss: 0.062627; Val Acc: 5.4473; Elapsed time: 27.8224
# Epoch: 001; Loss: 0.021064; Accuracy: 70.5935; Val Loss: 0.057103; Val Acc: 11.0135; Elapsed time: 32.8744
# Epoch: 002; Loss: 0.016994; Accuracy: 75.8270; Val Loss: 0.050804; Val Acc: 18.0998; Elapsed time: 35.7548
# Epoch: 003; Loss: 0.013943; Accuracy: 79.8771; Val Loss: 0.045145; Val Acc: 25.6057; Elapsed time: 32.7706
# Epoch: 004; Loss: 0.011617; Accuracy: 83.2564; Val Loss: 0.040336; Val Acc: 31.8527; Elapsed time: 28.3697
# Epoch: 005; Loss: 0.009821; Accuracy: 86.4011; Val Loss: 0.036251; Val Acc: 37.3713; Elapsed time: 25.4657
# Epoch: 006; Loss: 0.008427; Accuracy: 88.7602; Val Loss: 0.032898; Val Acc: 41.7736; Elapsed time: 29.6965
# Epoch: 007; Loss: 0.007330; Accuracy: 90.5583; Val Loss: 0.030330; Val Acc: 46.1758; Elapsed time: 28.9943
# Epoch: 008; Loss: 0.006449; Accuracy: 92.0095; Val Loss: 0.028119; Val Acc: 49.9762; Elapsed time: 31.9002
# Epoch: 009; Loss: 0.005735; Accuracy: 93.1419; Val Loss: 0.026306; Val Acc: 53.1037; Elapsed time: 29.5823
# Epoch: 010; Loss: 0.005146; Accuracy: 94.0498; Val Loss: 0.024708; Val Acc: 55.8036; Elapsed time: 28.5901
# Epoch: 011; Loss: 0.004652; Accuracy: 94.7869; Val Loss: 0.023334; Val Acc: 57.9256; Elapsed time: 36.8485
# Epoch: 012; Loss: 0.004233; Accuracy: 95.3965; Val Loss: 0.022161; Val Acc: 59.8971; Elapsed time: 33.1984
# Epoch: 013; Loss: 0.003873; Accuracy: 95.9219; Val Loss: 0.021012; Val Acc: 62.0032; Elapsed time: 29.3299
# Epoch: 014; Loss: 0.003564; Accuracy: 96.3452; Val Loss: 0.019985; Val Acc: 63.9272; Elapsed time: 25.7641
# Epoch: 015; Loss: 0.003296; Accuracy: 96.7558; Val Loss: 0.019083; Val Acc: 65.7007; Elapsed time: 31.7541
# Epoch: 016; Loss: 0.003061; Accuracy: 97.0517; Val Loss: 0.018171; Val Acc: 67.7118; Elapsed time: 31.9991
# Epoch: 017; Loss: 0.002853; Accuracy: 97.3220; Val Loss: 0.017310; Val Acc: 69.5566; Elapsed time: 31.2936
# Epoch: 018; Loss: 0.002668; Accuracy: 97.5490; Val Loss: 0.016550; Val Acc: 71.1718; Elapsed time: 24.8688
# Epoch: 019; Loss: 0.002503; Accuracy: 97.7607; Val Loss: 0.015795; Val Acc: 72.7791; Elapsed time: 31.0735
# Epoch: 020; Loss: 0.002353; Accuracy: 97.9571; Val Loss: 0.015129; Val Acc: 74.3626; Elapsed time: 31.2040
# Epoch: 021; Loss: 0.002218; Accuracy: 98.1407; Val Loss: 0.014492; Val Acc: 75.3444; Elapsed time: 29.1811
# Epoch: 022; Loss: 0.002095; Accuracy: 98.3295; Val Loss: 0.013955; Val Acc: 76.4925; Elapsed time: 28.7045
# Epoch: 023; Loss: 0.001983; Accuracy: 98.4493; Val Loss: 0.013451; Val Acc: 77.6010; Elapsed time: 31.1206
# Epoch: 024; Loss: 0.001881; Accuracy: 98.5565; Val Loss: 0.012990; Val Acc: 78.6698; Elapsed time: 25.1460
# Epoch: 025; Loss: 0.001786; Accuracy: 98.6763; Val Loss: 0.012577; Val Acc: 79.5012; Elapsed time: 31.6197
# Epoch: 026; Loss: 0.001700; Accuracy: 98.7707; Val Loss: 0.012176; Val Acc: 80.2613; Elapsed time: 31.1397
# Epoch: 027; Loss: 0.001620; Accuracy: 98.8600; Val Loss: 0.011801; Val Acc: 80.9422; Elapsed time: 24.4926
# Epoch: 028; Loss: 0.001546; Accuracy: 98.9110; Val Loss: 0.011456; Val Acc: 81.7261; Elapsed time: 31.4985
# Epoch: 029; Loss: 0.001477; Accuracy: 98.9849; Val Loss: 0.011137; Val Acc: 82.2328; Elapsed time: 28.0338
# Epoch: 030; Loss: 0.001414; Accuracy: 99.0512; Val Loss: 0.010846; Val Acc: 82.9770; Elapsed time: 29.7610
# Epoch: 031; Loss: 0.001355; Accuracy: 99.1431; Val Loss: 0.010568; Val Acc: 83.4600; Elapsed time: 32.2092
# Epoch: 032; Loss: 0.001300; Accuracy: 99.1966; Val Loss: 0.010303; Val Acc: 84.0855; Elapsed time: 25.8373
# Epoch: 033; Loss: 0.001249; Accuracy: 99.2578; Val Loss: 0.010056; Val Acc: 84.6952; Elapsed time: 31.7360
# Epoch: 034; Loss: 0.001202; Accuracy: 99.2935; Val Loss: 0.009827; Val Acc: 85.1148; Elapsed time: 32.6327
# Epoch: 035; Loss: 0.001158; Accuracy: 99.3216; Val Loss: 0.009617; Val Acc: 85.4473; Elapsed time: 31.6380
# Epoch: 036; Loss: 0.001117; Accuracy: 99.3522; Val Loss: 0.009406; Val Acc: 85.8116; Elapsed time: 26.7656
# Epoch: 037; Loss: 0.001078; Accuracy: 99.3751; Val Loss: 0.009212; Val Acc: 86.2470; Elapsed time: 28.6347
# Epoch: 038; Loss: 0.001041; Accuracy: 99.4109; Val Loss: 0.009024; Val Acc: 86.6825; Elapsed time: 28.5961
# Epoch: 039; Loss: 0.001007; Accuracy: 99.4466; Val Loss: 0.008863; Val Acc: 86.9675; Elapsed time: 26.4665
# Epoch: 040; Loss: 0.000975; Accuracy: 99.4772; Val Loss: 0.008701; Val Acc: 87.2922; Elapsed time: 31.2175
# Epoch: 041; Loss: 0.000944; Accuracy: 99.5001; Val Loss: 0.008554; Val Acc: 87.5059; Elapsed time: 26.0164
# Epoch: 042; Loss: 0.000916; Accuracy: 99.5307; Val Loss: 0.008411; Val Acc: 87.7831; Elapsed time: 28.1016
# Epoch: 043; Loss: 0.000889; Accuracy: 99.5664; Val Loss: 0.008273; Val Acc: 88.0206; Elapsed time: 26.6697
# Epoch: 044; Loss: 0.000864; Accuracy: 99.5919; Val Loss: 0.008143; Val Acc: 88.2581; Elapsed time: 31.5359
# Epoch: 045; Loss: 0.000839; Accuracy: 99.6098; Val Loss: 0.008014; Val Acc: 88.4877; Elapsed time: 34.1364
# Epoch: 046; Loss: 0.000816; Accuracy: 99.6200; Val Loss: 0.007888; Val Acc: 88.7094; Elapsed time: 26.4916
# Epoch: 047; Loss: 0.000794; Accuracy: 99.6276; Val Loss: 0.007764; Val Acc: 88.9232; Elapsed time: 29.0998
# Epoch: 048; Loss: 0.000773; Accuracy: 99.6378; Val Loss: 0.007649; Val Acc: 89.1607; Elapsed time: 24.6636
# Epoch: 049; Loss: 0.000753; Accuracy: 99.6506; Val Loss: 0.007536; Val Acc: 89.3428; Elapsed time: 30.6452
# Epoch: 050; Loss: 0.000734; Accuracy: 99.6582; Val Loss: 0.007432; Val Acc: 89.5249; Elapsed time: 28.6851
# Epoch: 051; Loss: 0.000715; Accuracy: 99.6710; Val Loss: 0.007328; Val Acc: 89.7229; Elapsed time: 35.8111
# Epoch: 052; Loss: 0.000697; Accuracy: 99.6812; Val Loss: 0.007235; Val Acc: 89.8654; Elapsed time: 31.5032
# Epoch: 053; Loss: 0.000680; Accuracy: 99.6991; Val Loss: 0.007138; Val Acc: 89.9762; Elapsed time: 30.9116
# Epoch: 054; Loss: 0.000663; Accuracy: 99.7118; Val Loss: 0.007050; Val Acc: 90.1584; Elapsed time: 26.6624
# Epoch: 055; Loss: 0.000647; Accuracy: 99.7246; Val Loss: 0.006967; Val Acc: 90.2850; Elapsed time: 29.7916
# Epoch: 056; Loss: 0.000631; Accuracy: 99.7271; Val Loss: 0.006883; Val Acc: 90.3563; Elapsed time: 27.2930
# Epoch: 057; Loss: 0.000616; Accuracy: 99.7297; Val Loss: 0.006793; Val Acc: 90.5701; Elapsed time: 28.0694
# Epoch: 058; Loss: 0.000602; Accuracy: 99.7450; Val Loss: 0.006720; Val Acc: 90.6968; Elapsed time: 31.4741
# Epoch: 059; Loss: 0.000588; Accuracy: 99.7577; Val Loss: 0.006632; Val Acc: 90.8155; Elapsed time: 24.1395
# Epoch: 060; Loss: 0.000575; Accuracy: 99.7705; Val Loss: 0.006542; Val Acc: 91.0214; Elapsed time: 29.3078
# Epoch: 061; Loss: 0.000563; Accuracy: 99.7730; Val Loss: 0.006466; Val Acc: 91.1401; Elapsed time: 29.4924
# Epoch: 062; Loss: 0.000550; Accuracy: 99.7909; Val Loss: 0.006391; Val Acc: 91.2985; Elapsed time: 33.6085
# Epoch: 063; Loss: 0.000538; Accuracy: 99.7960; Val Loss: 0.006319; Val Acc: 91.4648; Elapsed time: 31.5183
# Epoch: 064; Loss: 0.000527; Accuracy: 99.8036; Val Loss: 0.006254; Val Acc: 91.6073; Elapsed time: 24.1099
# Epoch: 065; Loss: 0.000516; Accuracy: 99.8062; Val Loss: 0.006187; Val Acc: 91.6865; Elapsed time: 31.0701
# Epoch: 066; Loss: 0.000505; Accuracy: 99.8062; Val Loss: 0.006129; Val Acc: 91.7894; Elapsed time: 24.7612
# Epoch: 067; Loss: 0.000494; Accuracy: 99.8087; Val Loss: 0.006068; Val Acc: 91.9002; Elapsed time: 31.1501
# Epoch: 068; Loss: 0.000484; Accuracy: 99.8113; Val Loss: 0.006003; Val Acc: 91.9952; Elapsed time: 23.9000
# Epoch: 069; Loss: 0.000474; Accuracy: 99.8215; Val Loss: 0.005940; Val Acc: 92.1457; Elapsed time: 31.2604
# Epoch: 070; Loss: 0.000465; Accuracy: 99.8240; Val Loss: 0.005884; Val Acc: 92.2882; Elapsed time: 28.8522
# Epoch: 071; Loss: 0.000456; Accuracy: 99.8317; Val Loss: 0.005837; Val Acc: 92.3674; Elapsed time: 26.3541
# Epoch: 072; Loss: 0.000447; Accuracy: 99.8419; Val Loss: 0.005781; Val Acc: 92.4149; Elapsed time: 27.6698
# Epoch: 073; Loss: 0.000438; Accuracy: 99.8521; Val Loss: 0.005732; Val Acc: 92.5178; Elapsed time: 29.4315
# Epoch: 074; Loss: 0.000430; Accuracy: 99.8648; Val Loss: 0.005676; Val Acc: 92.6287; Elapsed time: 35.3308
# Epoch: 075; Loss: 0.000421; Accuracy: 99.8674; Val Loss: 0.005627; Val Acc: 92.7158; Elapsed time: 28.3551
# Epoch: 076; Loss: 0.000413; Accuracy: 99.8674; Val Loss: 0.005580; Val Acc: 92.8028; Elapsed time: 28.6125
# Epoch: 077; Loss: 0.000405; Accuracy: 99.8699; Val Loss: 0.005537; Val Acc: 92.8820; Elapsed time: 23.8082
# Epoch: 078; Loss: 0.000398; Accuracy: 99.8699; Val Loss: 0.005491; Val Acc: 92.9374; Elapsed time: 30.7850
# Epoch: 079; Loss: 0.000391; Accuracy: 99.8725; Val Loss: 0.005450; Val Acc: 92.9770; Elapsed time: 27.3704
# Epoch: 080; Loss: 0.000383; Accuracy: 99.8750; Val Loss: 0.005409; Val Acc: 93.0325; Elapsed time: 26.8908
# Epoch: 081; Loss: 0.000377; Accuracy: 99.8776; Val Loss: 0.005374; Val Acc: 93.0800; Elapsed time: 26.2242
# Epoch: 082; Loss: 0.000370; Accuracy: 99.8776; Val Loss: 0.005337; Val Acc: 93.1037; Elapsed time: 27.4856
# Epoch: 083; Loss: 0.000363; Accuracy: 99.8827; Val Loss: 0.005302; Val Acc: 93.1591; Elapsed time: 29.5098
# Epoch: 084; Loss: 0.000357; Accuracy: 99.8852; Val Loss: 0.005265; Val Acc: 93.2066; Elapsed time: 27.1574
# Epoch: 085; Loss: 0.000350; Accuracy: 99.8903; Val Loss: 0.005232; Val Acc: 93.2462; Elapsed time: 28.9830
# Epoch: 086; Loss: 0.000344; Accuracy: 99.8903; Val Loss: 0.005196; Val Acc: 93.2858; Elapsed time: 27.0996
# Epoch: 087; Loss: 0.000339; Accuracy: 99.8929; Val Loss: 0.005162; Val Acc: 93.3650; Elapsed time: 28.4578
# Epoch: 088; Loss: 0.000333; Accuracy: 99.8980; Val Loss: 0.005133; Val Acc: 93.4046; Elapsed time: 30.8347
# Epoch: 089; Loss: 0.000327; Accuracy: 99.8980; Val Loss: 0.005102; Val Acc: 93.3888; Elapsed time: 25.3138
# Epoch: 090; Loss: 0.000322; Accuracy: 99.9005; Val Loss: 0.005071; Val Acc: 93.5075; Elapsed time: 29.9608
# Epoch: 091; Loss: 0.000316; Accuracy: 99.9056; Val Loss: 0.005043; Val Acc: 93.5471; Elapsed time: 25.5272
# Epoch: 092; Loss: 0.000311; Accuracy: 99.9082; Val Loss: 0.005014; Val Acc: 93.5946; Elapsed time: 25.7793
# Epoch: 093; Loss: 0.000306; Accuracy: 99.9107; Val Loss: 0.004989; Val Acc: 93.5946; Elapsed time: 30.9432
# Epoch: 094; Loss: 0.000301; Accuracy: 99.9107; Val Loss: 0.004960; Val Acc: 93.6342; Elapsed time: 33.9936
# Epoch: 095; Loss: 0.000296; Accuracy: 99.9107; Val Loss: 0.004936; Val Acc: 93.6659; Elapsed time: 34.3812
# Epoch: 096; Loss: 0.000292; Accuracy: 99.9133; Val Loss: 0.004908; Val Acc: 93.6738; Elapsed time: 29.0162
# Epoch: 097; Loss: 0.000287; Accuracy: 99.9133; Val Loss: 0.004884; Val Acc: 93.7609; Elapsed time: 28.1693
# Epoch: 098; Loss: 0.000283; Accuracy: 99.9158; Val Loss: 0.004860; Val Acc: 93.8005; Elapsed time: 31.6195
# Epoch: 099; Loss: 0.000279; Accuracy: 99.9158; Val Loss: 0.004837; Val Acc: 93.7926; Elapsed time: 26.4286
# Epoch: 100; Loss: 0.000274; Accuracy: 99.9158; Val Loss: 0.004813; Val Acc: 93.7926; Elapsed time: 29.9386
# Epoch: 101; Loss: 0.000270; Accuracy: 99.9184; Val Loss: 0.004792; Val Acc: 93.8084; Elapsed time: 31.6045
# Epoch: 102; Loss: 0.000266; Accuracy: 99.9184; Val Loss: 0.004772; Val Acc: 93.8401; Elapsed time: 24.7401
# Epoch: 103; Loss: 0.000262; Accuracy: 99.9209; Val Loss: 0.004753; Val Acc: 93.8401; Elapsed time: 30.2015
# Epoch: 104; Loss: 0.000259; Accuracy: 99.9235; Val Loss: 0.004731; Val Acc: 93.8717; Elapsed time: 28.5779
# Epoch: 105; Loss: 0.000255; Accuracy: 99.9235; Val Loss: 0.004710; Val Acc: 93.9034; Elapsed time: 31.2739
# Epoch: 106; Loss: 0.000251; Accuracy: 99.9235; Val Loss: 0.004695; Val Acc: 93.8876; Elapsed time: 24.5881
# Epoch: 107; Loss: 0.000248; Accuracy: 99.9260; Val Loss: 0.004675; Val Acc: 93.9509; Elapsed time: 31.6138
# Epoch: 108; Loss: 0.000244; Accuracy: 99.9286; Val Loss: 0.004658; Val Acc: 93.9509; Elapsed time: 26.6997
# Epoch: 109; Loss: 0.000241; Accuracy: 99.9337; Val Loss: 0.004638; Val Acc: 93.9430; Elapsed time: 28.9385
# Epoch: 110; Loss: 0.000238; Accuracy: 99.9362; Val Loss: 0.004619; Val Acc: 93.9588; Elapsed time: 31.2300
# Epoch: 111; Loss: 0.000234; Accuracy: 99.9439; Val Loss: 0.004600; Val Acc: 93.9826; Elapsed time: 24.5061
# Epoch: 112; Loss: 0.000231; Accuracy: 99.9464; Val Loss: 0.004583; Val Acc: 93.9905; Elapsed time: 28.0897
# Epoch: 113; Loss: 0.000228; Accuracy: 99.9464; Val Loss: 0.004565; Val Acc: 93.9984; Elapsed time: 28.2428
# Epoch: 114; Loss: 0.000225; Accuracy: 99.9490; Val Loss: 0.004548; Val Acc: 94.0063; Elapsed time: 31.4056
# Epoch: 115; Loss: 0.000222; Accuracy: 99.9515; Val Loss: 0.004529; Val Acc: 94.0459; Elapsed time: 31.2236
# Epoch: 116; Loss: 0.000219; Accuracy: 99.9541; Val Loss: 0.004512; Val Acc: 94.0697; Elapsed time: 24.4265
# Epoch: 117; Loss: 0.000216; Accuracy: 99.9541; Val Loss: 0.004496; Val Acc: 94.0934; Elapsed time: 30.8917
# Epoch: 118; Loss: 0.000214; Accuracy: 99.9566; Val Loss: 0.004477; Val Acc: 94.1093; Elapsed time: 24.5290
# Epoch: 119; Loss: 0.000211; Accuracy: 99.9566; Val Loss: 0.004459; Val Acc: 94.1568; Elapsed time: 30.6351
# Epoch: 120; Loss: 0.000208; Accuracy: 99.9617; Val Loss: 0.004441; Val Acc: 94.1409; Elapsed time: 26.1046
# Epoch: 121; Loss: 0.000206; Accuracy: 99.9617; Val Loss: 0.004425; Val Acc: 94.1568; Elapsed time: 29.3638
# Epoch: 122; Loss: 0.000203; Accuracy: 99.9617; Val Loss: 0.004406; Val Acc: 94.1726; Elapsed time: 28.1253
# Epoch: 123; Loss: 0.000201; Accuracy: 99.9617; Val Loss: 0.004389; Val Acc: 94.1726; Elapsed time: 27.8695
# Epoch: 124; Loss: 0.000198; Accuracy: 99.9617; Val Loss: 0.004372; Val Acc: 94.2201; Elapsed time: 33.7704
# Epoch: 125; Loss: 0.000196; Accuracy: 99.9617; Val Loss: 0.004354; Val Acc: 94.2439; Elapsed time: 29.1772
# Epoch: 126; Loss: 0.000193; Accuracy: 99.9643; Val Loss: 0.004339; Val Acc: 94.2359; Elapsed time: 27.6067
# Epoch: 127; Loss: 0.000191; Accuracy: 99.9643; Val Loss: 0.004324; Val Acc: 94.2835; Elapsed time: 31.1547
# Epoch: 128; Loss: 0.000189; Accuracy: 99.9643; Val Loss: 0.004307; Val Acc: 94.2914; Elapsed time: 24.8042
# Epoch: 129; Loss: 0.000187; Accuracy: 99.9668; Val Loss: 0.004291; Val Acc: 94.2993; Elapsed time: 31.0505
# Epoch: 130; Loss: 0.000184; Accuracy: 99.9668; Val Loss: 0.004278; Val Acc: 94.3072; Elapsed time: 24.6402
# Epoch: 131; Loss: 0.000182; Accuracy: 99.9668; Val Loss: 0.004263; Val Acc: 94.3230; Elapsed time: 31.1706
# Epoch: 132; Loss: 0.000180; Accuracy: 99.9694; Val Loss: 0.004249; Val Acc: 94.3230; Elapsed time: 24.4267
# Epoch: 133; Loss: 0.000178; Accuracy: 99.9694; Val Loss: 0.004235; Val Acc: 94.3389; Elapsed time: 31.1734
# Epoch: 134; Loss: 0.000176; Accuracy: 99.9694; Val Loss: 0.004223; Val Acc: 94.3626; Elapsed time: 24.8681
# Epoch: 135; Loss: 0.000174; Accuracy: 99.9694; Val Loss: 0.004209; Val Acc: 94.3864; Elapsed time: 31.7013
# Epoch: 136; Loss: 0.000172; Accuracy: 99.9694; Val Loss: 0.004196; Val Acc: 94.4181; Elapsed time: 25.2888
# Epoch: 137; Loss: 0.000170; Accuracy: 99.9719; Val Loss: 0.004185; Val Acc: 94.4418; Elapsed time: 30.8323
# Epoch: 138; Loss: 0.000169; Accuracy: 99.9719; Val Loss: 0.004171; Val Acc: 94.4418; Elapsed time: 27.4336
# Epoch: 139; Loss: 0.000167; Accuracy: 99.9745; Val Loss: 0.004159; Val Acc: 94.4656; Elapsed time: 27.9279
# Epoch: 140; Loss: 0.000165; Accuracy: 99.9745; Val Loss: 0.004145; Val Acc: 94.4735; Elapsed time: 31.3094
# Epoch: 141; Loss: 0.000163; Accuracy: 99.9745; Val Loss: 0.004133; Val Acc: 94.4893; Elapsed time: 34.1047
# Epoch: 142; Loss: 0.000161; Accuracy: 99.9745; Val Loss: 0.004119; Val Acc: 94.4972; Elapsed time: 30.8437
# Epoch: 143; Loss: 0.000160; Accuracy: 99.9745; Val Loss: 0.004108; Val Acc: 94.5051; Elapsed time: 33.2152
# Epoch: 144; Loss: 0.000158; Accuracy: 99.9745; Val Loss: 0.004096; Val Acc: 94.4972; Elapsed time: 29.9971
# Epoch: 145; Loss: 0.000156; Accuracy: 99.9745; Val Loss: 0.004084; Val Acc: 94.5051; Elapsed time: 30.6800
# Epoch: 146; Loss: 0.000155; Accuracy: 99.9745; Val Loss: 0.004071; Val Acc: 94.5289; Elapsed time: 34.0991
# Epoch: 147; Loss: 0.000153; Accuracy: 99.9745; Val Loss: 0.004060; Val Acc: 94.5289; Elapsed time: 26.6312
# Epoch: 148; Loss: 0.000151; Accuracy: 99.9745; Val Loss: 0.004049; Val Acc: 94.5527; Elapsed time: 29.1913
# Epoch: 149; Loss: 0.000150; Accuracy: 99.9745; Val Loss: 0.004038; Val Acc: 94.5527; Elapsed time: 31.5205
# Epoch: 150; Loss: 0.000148; Accuracy: 99.9771; Val Loss: 0.004027; Val Acc: 94.5527; Elapsed time: 27.1300
# Epoch: 151; Loss: 0.000147; Accuracy: 99.9771; Val Loss: 0.004017; Val Acc: 94.5606; Elapsed time: 33.3508
# Epoch: 152; Loss: 0.000145; Accuracy: 99.9771; Val Loss: 0.004006; Val Acc: 94.5922; Elapsed time: 37.2454
# Epoch: 153; Loss: 0.000144; Accuracy: 99.9771; Val Loss: 0.003996; Val Acc: 94.6081; Elapsed time: 34.6729
# Epoch: 154; Loss: 0.000143; Accuracy: 99.9821; Val Loss: 0.003985; Val Acc: 94.6160; Elapsed time: 34.4439
# Epoch: 155; Loss: 0.000141; Accuracy: 99.9821; Val Loss: 0.003974; Val Acc: 94.6318; Elapsed time: 36.4701
# Epoch: 156; Loss: 0.000140; Accuracy: 99.9821; Val Loss: 0.003964; Val Acc: 94.6318; Elapsed time: 33.6156
# Epoch: 157; Loss: 0.000138; Accuracy: 99.9821; Val Loss: 0.003954; Val Acc: 94.6397; Elapsed time: 27.2124
# Epoch: 158; Loss: 0.000137; Accuracy: 99.9847; Val Loss: 0.003943; Val Acc: 94.6477; Elapsed time: 29.9685
# Epoch: 159; Loss: 0.000136; Accuracy: 99.9873; Val Loss: 0.003933; Val Acc: 94.6635; Elapsed time: 23.8577
# Epoch: 160; Loss: 0.000134; Accuracy: 99.9873; Val Loss: 0.003924; Val Acc: 94.6714; Elapsed time: 29.9755
# Epoch: 161; Loss: 0.000133; Accuracy: 99.9873; Val Loss: 0.003914; Val Acc: 94.6952; Elapsed time: 28.3778
# Epoch: 162; Loss: 0.000132; Accuracy: 99.9873; Val Loss: 0.003905; Val Acc: 94.7189; Elapsed time: 25.4126
# Epoch: 163; Loss: 0.000131; Accuracy: 99.9873; Val Loss: 0.003895; Val Acc: 94.7189; Elapsed time: 24.1659
# Epoch: 164; Loss: 0.000129; Accuracy: 99.9873; Val Loss: 0.003885; Val Acc: 94.7348; Elapsed time: 26.7116
# Epoch: 165; Loss: 0.000128; Accuracy: 99.9898; Val Loss: 0.003876; Val Acc: 94.7348; Elapsed time: 24.6056
# Epoch: 166; Loss: 0.000127; Accuracy: 99.9923; Val Loss: 0.003868; Val Acc: 94.7189; Elapsed time: 23.3533
# Epoch: 167; Loss: 0.000126; Accuracy: 99.9923; Val Loss: 0.003859; Val Acc: 94.7189; Elapsed time: 24.8142
# Epoch: 168; Loss: 0.000125; Accuracy: 99.9923; Val Loss: 0.003850; Val Acc: 94.7031; Elapsed time: 27.8615
# Epoch: 169; Loss: 0.000123; Accuracy: 99.9923; Val Loss: 0.003842; Val Acc: 94.7031; Elapsed time: 24.0991
# Epoch: 170; Loss: 0.000122; Accuracy: 99.9923; Val Loss: 0.003835; Val Acc: 94.7189; Elapsed time: 29.6920
# Epoch: 171; Loss: 0.000121; Accuracy: 99.9923; Val Loss: 0.003826; Val Acc: 94.7268; Elapsed time: 24.1209
# Epoch: 172; Loss: 0.000120; Accuracy: 99.9923; Val Loss: 0.003818; Val Acc: 94.7348; Elapsed time: 29.4974
# Epoch: 173; Loss: 0.000119; Accuracy: 99.9923; Val Loss: 0.003809; Val Acc: 94.7348; Elapsed time: 25.7334
# Epoch: 174; Loss: 0.000118; Accuracy: 99.9923; Val Loss: 0.003802; Val Acc: 94.7268; Elapsed time: 23.9158
# Epoch: 175; Loss: 0.000117; Accuracy: 99.9923; Val Loss: 0.003793; Val Acc: 94.7189; Elapsed time: 25.5499
# Epoch: 176; Loss: 0.000116; Accuracy: 99.9923; Val Loss: 0.003785; Val Acc: 94.7189; Elapsed time: 27.9263
# Epoch: 177; Loss: 0.000115; Accuracy: 99.9923; Val Loss: 0.003778; Val Acc: 94.7110; Elapsed time: 29.5433
# Epoch: 178; Loss: 0.000114; Accuracy: 99.9923; Val Loss: 0.003770; Val Acc: 94.7110; Elapsed time: 29.0621
# Epoch: 179; Loss: 0.000113; Accuracy: 99.9923; Val Loss: 0.003762; Val Acc: 94.7189; Elapsed time: 26.8715
# Epoch: 180; Loss: 0.000112; Accuracy: 99.9949; Val Loss: 0.003754; Val Acc: 94.7268; Elapsed time: 27.7403
# Epoch: 181; Loss: 0.000111; Accuracy: 99.9949; Val Loss: 0.003746; Val Acc: 94.7348; Elapsed time: 28.3154
# Epoch: 182; Loss: 0.000110; Accuracy: 100.0000; Val Loss: 0.003738; Val Acc: 94.7427; Elapsed time: 23.9296
# Epoch: 183; Loss: 0.000109; Accuracy: 100.0000; Val Loss: 0.003731; Val Acc: 94.7585; Elapsed time: 27.4062
# Epoch: 184; Loss: 0.000108; Accuracy: 100.0000; Val Loss: 0.003722; Val Acc: 94.7743; Elapsed time: 32.2420
# Epoch: 185; Loss: 0.000107; Accuracy: 100.0000; Val Loss: 0.003716; Val Acc: 94.7743; Elapsed time: 35.6916
# Epoch: 186; Loss: 0.000106; Accuracy: 100.0000; Val Loss: 0.003709; Val Acc: 94.7743; Elapsed time: 35.8632
# Epoch: 187; Loss: 0.000105; Accuracy: 100.0000; Val Loss: 0.003702; Val Acc: 94.7981; Elapsed time: 37.3420

# %%
vcpi_util.show_histories([history], ['yep'], 'val_acc')

# %% [markdown]
# ### Test Model

# %%
evaluate(model, test_loader)
# Out:
# 0.03737133741378784

# %%
build_confusion_matrix(model, test_loader)

# %%
preds = []
ground_truth = []

for images, targets in test_loader:

    logits = model(images.to(device))
    preds_aux = [np.argmax(x) for x in logits.cpu().detach().numpy()]
    preds.extend(preds_aux)
    ground_truth.extend(targets.numpy())

vcpi_util.show_confusion_matrix(ground_truth, preds, 43)

# %%
target_list = []

for images, targets in train_loader:

    target_list.extend(targets)

vcpi_util.show_histogram(target_list, train_set.classes)
# Out:
# Counter({2: 2250, 1: 2220, 13: 2160, 12: 2100, 38: 2070, 10: 2010, 4: 1980, 5: 1860, 25: 1500, 9: 1470, 7: 1440, 3: 1410, 8: 1410, 11: 1320, 18: 1200, 35: 1200, 17: 1110, 14: 780, 31: 780, 33: 689, 15: 630, 26: 600, 28: 540, 23: 510, 30: 450, 6: 420, 16: 420, 34: 420, 22: 390, 36: 390, 20: 360, 40: 360, 21: 330, 39: 300, 24: 270, 29: 270, 27: 240, 32: 240, 41: 240, 42: 240, 0: 210, 19: 210, 37: 210})

# %%
#Evaluate without transformatios on test

test_transform = v2.Compose([
        v2.ToImage(),
        v2.Resize((IMG_SIZE, IMG_SIZE)),   
        v2.ToDtype(torch.float32, scale=True),
])

test_set = torchvision.datasets.ImageFolder(root=PATH_TEST_SET, transform = test_transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size = BATCH_SIZE)

evaluate(model, test_loader)
# Out:
# 0.035471100360155106

# %%
#Load the models and change the tests transformations here:

retrieved = torch.load(f'models/model_2.pt')

model.load_state_dict(retrieved['model'])
model.to(device)

optimizer.load_state_dict(retrieved['optimizer'])

test_transform = v2.Compose([
        v2.Resize((IMG_SIZE + 6, IMG_SIZE + 6)),
        v2.CenterCrop(size=(IMG_SIZE, IMG_SIZE)),
        #v2.ToTensor(),
        v2.ToImage(),
        #v2.Grayscale(num_output_channels=3),
        #v2.AutoAugment(),
        #v2.ColorJitter(brightness=0.1, contrast=0.2, saturation=0.2),
        v2.ToDtype(torch.float32, scale=True),
        #v2.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

test_set = torchvision.datasets.ImageFolder(root=PATH_TEST_SET, transform = test_transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size = BATCH_SIZE)

evaluate(model, test_loader)
# Out:
# 0.7874109148979187
