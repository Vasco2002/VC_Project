# %%
import torch
import torchvision

import torchinfo

import matplotlib.pyplot as plt
import numpy as np
import time

# importing a module with utilities for displaying stats and data
import sys
sys.path.insert(1, 'util')
import vcpi_util

# %% [markdown]
# ### Init device

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else 'cpu')
print(torch.__version__)
print(device)
# Out:
# 2.2.1+cu121
# cuda:0

# %% [markdown]
# ### Settings

# %%
BATCH_SIZE = 64
EPOCKS = 20
IMG_SIZE = 32
EPOCHS = 1000

PATH_TRAINING_SET = "data/train_images/GTSRB/Final_Training/Images"
PATH_TEST_SET = "data/test_images"

# %% [markdown]
# ### Model Building Aux

# %%
def train(model, data_loader, epochs, loss_fn, optimizer):

    # sets the model in training mode.
    # although our model does not have layers which behave differently during training and evaluation
    # this is a good practice as the models architecture may change in the future
    model.train()

    history = {}
    history['accuracy'] = []
    history['loss'] = []

    for epoch in range(epochs):  # loop over the dataset multiple times

        start_time = time.time() 
        correct = 0
        running_loss = 0.0
        for i, (inputs, targets) in enumerate(data_loader, 0):
            
            # send data to device, hopefully the GPU
            inputs = inputs.to(device)
            targets = targets.to(device)

            # forward pass, compute the output of the model for the current batch
            outputs = model(inputs)


            _, predicted = torch.max(outputs, 1)

            #compute the loss between the model's outputs and the labels, or targets.
            loss = loss_fn(outputs, targets)
            
            # zero the parameter gradients
            # this function must be called before calling "backward" on the losses, otherwise the gradients get accumulated with previous batches.
            optimizer.zero_grad()

            # perform backpropagation
            loss.backward()
            #update the model's parameters
            optimizer.step()

            running_loss += loss
            correct += (predicted == targets).sum()

        accuracy = 100 * correct / len(train_set)
        stop_time = time.time()
        print(f'Epoch: {epoch:03d}; Accuracy = {accuracy:0.4f}; Elapsed time: {(stop_time - start_time):0.4f}')
        history['accuracy'].append(accuracy.cpu().numpy())
        history['loss'].append(running_loss.cpu().detach().numpy())
        
    print('Finished Training')

    return history

def train2(model, train_loader, val_loader, epochs, loss_fn, optimizer,
           scheduler, early_stopper, save_prefix = 'model'):

    history = {}
    history['accuracy'] = []
    history['val_acc'] = []
    history['val_loss'] = []
    history['loss'] = []
    best_val_loss = np.inf

    for epoch in range(epochs):  # loop over the dataset multiple times

        model.train()
        start_time = time.time() 
        correct = 0
        running_loss = 0.0
        for i, (inputs, targets) in enumerate(train_loader, 0):
            
            inputs = inputs.to(device)
            targets = targets.to(device)

            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)

            loss = loss_fn(outputs, targets)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss
            correct += (predicted == targets).sum()

        model.eval()
        v_correct = 0
        val_loss = 0.0
        with torch.no_grad():
            for i,t in val_loader:
                i = i.to(device)
                t = t.to(device)
                o = model(i)
                _,p = torch.max(o,1)
                
                #with torch.no_grad():
                val_loss += loss_fn(o, t)

                v_correct += (p == t).sum()

        old_lr = optimizer.param_groups[0]['lr']
        scheduler.step(val_loss)
        new_lr = optimizer.param_groups[0]['lr']
        
        if old_lr != new_lr:
            print('==> Learning rate updated: ', old_lr, ' -> ', new_lr)

        epoch_loss = running_loss / len(train_loader.dataset)
        accuracy = 100 * correct / len(train_loader.dataset)
        v_accuracy = 100 * v_correct / len(val_loader.dataset)
        val_loss = val_loss / len(val_loader.dataset)
        stop_time = time.time()
        print(f'Epoch: {epoch:03d}; Loss: {epoch_loss:0.6f}; Accuracy: {accuracy:0.4f}; Val Loss: {val_loss:0.6f}; Val Acc: {v_accuracy:0.4f}; Elapsed time: {(stop_time - start_time):0.4f}')
        history['accuracy'].append(accuracy.cpu().numpy())
        history['val_acc'].append(v_accuracy.cpu().numpy())
        history['val_loss'].append(val_loss.cpu().detach().numpy())
        history['loss'].append(epoch_loss.cpu().detach().numpy())
 
        ###### Saving ######
        if val_loss < best_val_loss:
           
            torch.save({
                'epoch': epoch,
                'model':model.state_dict(),
                'optimizer': optimizer.state_dict(),
                'scheduler': scheduler.state_dict()
                },
                f'models/{save_prefix}.pt')

        if early_stopper(val_loss):
            print('Early stopping!')
            break
        
    print('Finished Training')

    return(history)


def evaluate(model, data_loader):

    # sets the model in evaluation mode.
    # although our model does not have layers which behave differently during training and evaluation
    # this is a good practice as the models architecture may change in the future
    model.eval()

    correct = 0
    
    for i, (images, targets) in enumerate(data_loader):
         
        # forward pass, compute the output of the model for the current batch
        outputs = model(images.to(device))

        # "max" returns a namedtuple (values, indices) where values is the maximum 
        # value of each row of the input tensor in the given dimension dim; 
        # indices is the index location of each maximum value found (argmax).
        # the argmax effectively provides the predicted class number        
        _, preds = torch.max(outputs, dim=1)

        correct += (preds.cpu() == targets).sum()

    return (correct / len(data_loader.dataset)).item()


class Conv(torch.nn.Module):

    def __init__(self, num_classes):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(3, 16, 3)
        self.bn1 = torch.nn.BatchNorm2d(16)
        self.relu1 = torch.nn.ReLU()

        self.conv2 = torch.nn.Conv2d(16, 32, 3)
        self.bn2 = torch.nn.BatchNorm2d(32)
        self.relu2 = torch.nn.ReLU()

        self.maxpool1 = torch.nn.MaxPool2d(2)


        self.conv3 = torch.nn.Conv2d(32, 48, 3)
        self.bn3 = torch.nn.BatchNorm2d(48)
        self.relu3 = torch.nn.ReLU()

        self.conv4 = torch.nn.Conv2d(48, 48, 3)
        self.bn4 = torch.nn.BatchNorm2d(48)
        self.relu4 = torch.nn.ReLU()

        self.maxpool2 = torch.nn.MaxPool2d(2)

        self.fc1 = torch.nn.Linear(1200, num_classes)
        

    def forward(self, x):    
        
        # input = (bs, 3, 32, 32)
        x = self.conv1(x) # -> (bs, 16, 30, 30)
        x = self.bn1(x)
        x = self.relu1(x)
        x = self.conv2(x) # -> (bs, 32, 28, 28)
        x = self.bn2(x)
        x = self.relu2(x)
        x = self.maxpool1(x) # -> (bs, 32, 14, 14)
        
        x = self.conv3(x) # -> (bs, 48, 12, 12)
        x = self.bn3(x)
        x = self.relu3(x)
        x = self.conv4(x) # -> (bs, 48, 10, 10)
        x = self.bn4(x)
        x = self.relu4(x)
        x = self.maxpool2(x) # -> (bs, 48, 5, 5)
        
        x = torch.flatten(x,1) # -> (bs, 48 * 5 * 5 = 1200)
        x = self.fc1(x)        # -> (bs, num_classes)

        return(x)


class Early_Stopping():

    def __init__(self, patience = 3, min_delta = 0.00001):

        self.patience = patience 
        self.min_delta = min_delta

        self.min_delta
        self.min_val_loss = float('inf')

    def __call__(self, val_loss):

        # improvement
        if val_loss + self.min_delta < self.min_val_loss:
            self.min_val_loss = val_loss
            self.counter = 0

        # no improvement            
        else:
            self.counter += 1
            if self.counter > self.patience:
                return True
            
        return False
    


def build_confusion_matrix(model, dataset):

    preds = []
    ground_truth = []

    for images, targets in dataset:

        predictions = model(images.to(device))
        preds_sparse = [np.argmax(x) for x in predictions.cpu().detach().numpy()]
        preds.extend(preds_sparse)
        ground_truth.extend(targets.numpy())

    vcpi_util.show_confusion_matrix(ground_truth, preds, len(test_set.classes)) 

def build_confusion_matrix2(model, dataset, class_names):
    preds = []
    ground_truth = []

    for images, targets in dataset:
        predictions = model(images.to(device))
        preds_sparse = [np.argmax(x) for x in predictions.cpu().detach().numpy()]
        preds.extend(preds_sparse)
        ground_truth.extend(targets.numpy())

    num_classes = len(class_names) if class_names else len(set(ground_truth))
    vcpi_util.show_confusion_matrix(ground_truth, preds, len(test_set.classes))

# %% [markdown]
# ## Model with Transform Set 1
# ### Data Loading

# %%
from torchvision.transforms import v2


train_transform = v2.Compose([
        v2.ToImage(),
        v2.Resize((IMG_SIZE + 6, IMG_SIZE + 6)),
        v2.CenterCrop(size=(IMG_SIZE, IMG_SIZE)),
        v2.RandomErasing(p=1, scale=(0.02, 0.1), ratio=(0.3, 3.3), value='random'),
        v2.ColorJitter(contrast=(1.4, 1.4)),
        v2.ToDtype(torch.float32, scale=True),
])

test_transform = v2.Compose([
        v2.ToImage(),
        v2.Resize((IMG_SIZE + 4, IMG_SIZE + 4)),
        v2.CenterCrop(size=(IMG_SIZE, IMG_SIZE)),
        v2.RandomErasing(p=1, scale=(0.02, 0.1), ratio=(0.3, 3.3), value='random'),
        v2.ColorJitter(contrast=(1.4, 1.4)),
        v2.ToDtype(torch.float32, scale=True),
])

# %%
# No shuffle is required for the test set, also the batch size can be completely different
test_set = torchvision.datasets.ImageFolder(root=PATH_TEST_SET, transform = test_transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size = BATCH_SIZE)

train_set = torchvision.datasets.ImageFolder(root=PATH_TRAINING_SET, transform = train_transform)
train_loader = torch.utils.data.DataLoader(train_set, batch_size = BATCH_SIZE)

# %%
images, targets = next(iter(train_loader))
vcpi_util.show_images(4,8,images,targets,train_set.classes)

# %% [markdown]
# ### Model Training

# %%
model = Conv(len(train_set.classes))
model.to(device)

optimizer = torch.optim.SGD(model.parameters())
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor = 0.1, patience=3)
loss_fn = torch.nn.CrossEntropyLoss()

early_stop = Early_Stopping(9)

# %%
history = train2(
    model, train_loader, test_loader, 
    EPOCHS, loss_fn, optimizer, scheduler, early_stop, 'model_7')
# Out:
# Epoch: 000; Loss: 0.029138; Accuracy: 60.2362; Val Loss: 0.063798; Val Acc: 5.8907; Elapsed time: 87.7231
# Epoch: 001; Loss: 0.026690; Accuracy: 62.0878; Val Loss: 0.061347; Val Acc: 8.6698; Elapsed time: 85.6643
# Epoch: 002; Loss: 0.022411; Accuracy: 67.4080; Val Loss: 0.057273; Val Acc: 12.0903; Elapsed time: 80.9402
# Epoch: 003; Loss: 0.019028; Accuracy: 71.9962; Val Loss: 0.053084; Val Acc: 16.6508; Elapsed time: 78.9619
# Epoch: 004; Loss: 0.016324; Accuracy: 75.9953; Val Loss: 0.049278; Val Acc: 19.7387; Elapsed time: 72.7959
# Epoch: 005; Loss: 0.014248; Accuracy: 79.1502; Val Loss: 0.045790; Val Acc: 23.3650; Elapsed time: 73.9295
# Epoch: 006; Loss: 0.012593; Accuracy: 81.3818; Val Loss: 0.042579; Val Acc: 27.1496; Elapsed time: 80.2713
# Epoch: 007; Loss: 0.011239; Accuracy: 83.4706; Val Loss: 0.039906; Val Acc: 30.2613; Elapsed time: 63.0854
# Epoch: 008; Loss: 0.010162; Accuracy: 85.2636; Val Loss: 0.037805; Val Acc: 32.6762; Elapsed time: 68.5523
# Epoch: 009; Loss: 0.009297; Accuracy: 86.5107; Val Loss: 0.035695; Val Acc: 35.5424; Elapsed time: 68.8255
# Epoch: 010; Loss: 0.008568; Accuracy: 87.5003; Val Loss: 0.034221; Val Acc: 38.4006; Elapsed time: 68.6554
# Epoch: 011; Loss: 0.007884; Accuracy: 88.5307; Val Loss: 0.032697; Val Acc: 40.4276; Elapsed time: 69.2547
# Epoch: 012; Loss: 0.007373; Accuracy: 89.3392; Val Loss: 0.031272; Val Acc: 42.7395; Elapsed time: 69.8894
# Epoch: 013; Loss: 0.006887; Accuracy: 90.0150; Val Loss: 0.030368; Val Acc: 44.2359; Elapsed time: 68.8168
# Epoch: 014; Loss: 0.006515; Accuracy: 90.6272; Val Loss: 0.029284; Val Acc: 45.6849; Elapsed time: 68.3096
# Epoch: 015; Loss: 0.006125; Accuracy: 91.2852; Val Loss: 0.028588; Val Acc: 46.6904; Elapsed time: 68.1886
# Epoch: 016; Loss: 0.005813; Accuracy: 91.6907; Val Loss: 0.027654; Val Acc: 48.5986; Elapsed time: 68.9855
# Epoch: 017; Loss: 0.005490; Accuracy: 92.1625; Val Loss: 0.026893; Val Acc: 49.2953; Elapsed time: 62.9193
# Epoch: 018; Loss: 0.005271; Accuracy: 92.4329; Val Loss: 0.026055; Val Acc: 50.1821; Elapsed time: 69.0549
# Epoch: 019; Loss: 0.005000; Accuracy: 92.9863; Val Loss: 0.025649; Val Acc: 51.2114; Elapsed time: 65.7022
# Epoch: 020; Loss: 0.004809; Accuracy: 93.2720; Val Loss: 0.024976; Val Acc: 51.7260; Elapsed time: 66.5989
# Epoch: 021; Loss: 0.004577; Accuracy: 93.7030; Val Loss: 0.024401; Val Acc: 52.9454; Elapsed time: 68.0281
# Epoch: 022; Loss: 0.004399; Accuracy: 93.9835; Val Loss: 0.023758; Val Acc: 53.9747; Elapsed time: 63.2999
# Epoch: 023; Loss: 0.004245; Accuracy: 94.1340; Val Loss: 0.023124; Val Acc: 55.3761; Elapsed time: 69.1270
# Epoch: 024; Loss: 0.004056; Accuracy: 94.4146; Val Loss: 0.022898; Val Acc: 55.7165; Elapsed time: 69.8984
# Epoch: 025; Loss: 0.003926; Accuracy: 94.6466; Val Loss: 0.022277; Val Acc: 56.8567; Elapsed time: 64.8588
# Epoch: 026; Loss: 0.003745; Accuracy: 94.9476; Val Loss: 0.021645; Val Acc: 57.9018; Elapsed time: 68.2017
# Epoch: 027; Loss: 0.003651; Accuracy: 95.0139; Val Loss: 0.021055; Val Acc: 58.5590; Elapsed time: 68.1110
# Epoch: 028; Loss: 0.003497; Accuracy: 95.2664; Val Loss: 0.020907; Val Acc: 59.3983; Elapsed time: 67.9523
# Epoch: 029; Loss: 0.003409; Accuracy: 95.4296; Val Loss: 0.020536; Val Acc: 60.2059; Elapsed time: 61.9950
# Epoch: 030; Loss: 0.003294; Accuracy: 95.5903; Val Loss: 0.020253; Val Acc: 60.7284; Elapsed time: 68.3134
# Epoch: 031; Loss: 0.003210; Accuracy: 95.6668; Val Loss: 0.019723; Val Acc: 61.9082; Elapsed time: 68.8043
# Epoch: 032; Loss: 0.003101; Accuracy: 95.9091; Val Loss: 0.019231; Val Acc: 62.6049; Elapsed time: 65.3613
# Epoch: 033; Loss: 0.003030; Accuracy: 95.9372; Val Loss: 0.019057; Val Acc: 62.8424; Elapsed time: 68.7176
# Epoch: 034; Loss: 0.002936; Accuracy: 96.1029; Val Loss: 0.018778; Val Acc: 64.0934; Elapsed time: 63.6713
# Epoch: 035; Loss: 0.002836; Accuracy: 96.1871; Val Loss: 0.018492; Val Acc: 64.4893; Elapsed time: 68.6714
# Epoch: 036; Loss: 0.002802; Accuracy: 96.2534; Val Loss: 0.017975; Val Acc: 65.9462; Elapsed time: 69.4440
# Epoch: 037; Loss: 0.002705; Accuracy: 96.4677; Val Loss: 0.017730; Val Acc: 66.0966; Elapsed time: 63.0285
# Epoch: 038; Loss: 0.002650; Accuracy: 96.5034; Val Loss: 0.017435; Val Acc: 66.8013; Elapsed time: 68.7193
# Epoch: 039; Loss: 0.002568; Accuracy: 96.7584; Val Loss: 0.017066; Val Acc: 67.5851; Elapsed time: 62.7119
# Epoch: 040; Loss: 0.002513; Accuracy: 96.7252; Val Loss: 0.017054; Val Acc: 67.8147; Elapsed time: 69.1551
# Epoch: 041; Loss: 0.002448; Accuracy: 96.7890; Val Loss: 0.016817; Val Acc: 68.4877; Elapsed time: 63.1720
# Epoch: 042; Loss: 0.002425; Accuracy: 96.7303; Val Loss: 0.016684; Val Acc: 68.4006; Elapsed time: 69.6738
# Epoch: 043; Loss: 0.002368; Accuracy: 96.8783; Val Loss: 0.016498; Val Acc: 68.8915; Elapsed time: 69.2582
# Epoch: 044; Loss: 0.002315; Accuracy: 96.9293; Val Loss: 0.016193; Val Acc: 69.4695; Elapsed time: 69.8758
# Epoch: 045; Loss: 0.002273; Accuracy: 97.1282; Val Loss: 0.016038; Val Acc: 69.7625; Elapsed time: 63.0641
# Epoch: 046; Loss: 0.002195; Accuracy: 97.2761; Val Loss: 0.015808; Val Acc: 70.9184; Elapsed time: 68.2315
# Epoch: 047; Loss: 0.002147; Accuracy: 97.3144; Val Loss: 0.015545; Val Acc: 71.3223; Elapsed time: 68.6921
# Epoch: 048; Loss: 0.002124; Accuracy: 97.2455; Val Loss: 0.015561; Val Acc: 71.5756; Elapsed time: 68.8656
# Epoch: 049; Loss: 0.002079; Accuracy: 97.4215; Val Loss: 0.015288; Val Acc: 71.7261; Elapsed time: 62.2596
# Epoch: 050; Loss: 0.002048; Accuracy: 97.3680; Val Loss: 0.015194; Val Acc: 71.8369; Elapsed time: 69.3437
# Epoch: 051; Loss: 0.002003; Accuracy: 97.4802; Val Loss: 0.014976; Val Acc: 72.5574; Elapsed time: 69.5824
# Epoch: 052; Loss: 0.001959; Accuracy: 97.5541; Val Loss: 0.014492; Val Acc: 73.3492; Elapsed time: 64.1782
# Epoch: 053; Loss: 0.001929; Accuracy: 97.5618; Val Loss: 0.014609; Val Acc: 73.3571; Elapsed time: 66.6825
# Epoch: 054; Loss: 0.001924; Accuracy: 97.5388; Val Loss: 0.014494; Val Acc: 73.4125; Elapsed time: 69.0291
# Epoch: 055; Loss: 0.001890; Accuracy: 97.5592; Val Loss: 0.014663; Val Acc: 73.1829; Elapsed time: 65.5629
# Epoch: 056; Loss: 0.001849; Accuracy: 97.6919; Val Loss: 0.014331; Val Acc: 74.0380; Elapsed time: 67.6445
# Epoch: 057; Loss: 0.001816; Accuracy: 97.6485; Val Loss: 0.014267; Val Acc: 74.1409; Elapsed time: 69.0759
# Epoch: 058; Loss: 0.001790; Accuracy: 97.6970; Val Loss: 0.014103; Val Acc: 74.7427; Elapsed time: 68.3604
# Epoch: 059; Loss: 0.001737; Accuracy: 97.7684; Val Loss: 0.013919; Val Acc: 75.2732; Elapsed time: 67.5989
# Epoch: 060; Loss: 0.001724; Accuracy: 97.7913; Val Loss: 0.014033; Val Acc: 74.8298; Elapsed time: 63.2343
# Epoch: 061; Loss: 0.001666; Accuracy: 97.9852; Val Loss: 0.013671; Val Acc: 75.2257; Elapsed time: 68.4001
# Epoch: 062; Loss: 0.001671; Accuracy: 97.8423; Val Loss: 0.013593; Val Acc: 75.6532; Elapsed time: 68.1028
# Epoch: 063; Loss: 0.001652; Accuracy: 97.9163; Val Loss: 0.013509; Val Acc: 75.6374; Elapsed time: 63.3804
# Epoch: 064; Loss: 0.001608; Accuracy: 97.9801; Val Loss: 0.013518; Val Acc: 75.8195; Elapsed time: 67.5281
# Epoch: 065; Loss: 0.001617; Accuracy: 97.9290; Val Loss: 0.013527; Val Acc: 75.5661; Elapsed time: 68.2639
# Epoch: 066; Loss: 0.001568; Accuracy: 97.9954; Val Loss: 0.013313; Val Acc: 76.4054; Elapsed time: 67.7445
# Epoch: 067; Loss: 0.001536; Accuracy: 98.0668; Val Loss: 0.013074; Val Acc: 76.5004; Elapsed time: 68.0217
# Epoch: 068; Loss: 0.001556; Accuracy: 98.0515; Val Loss: 0.012998; Val Acc: 76.9279; Elapsed time: 62.5028
# Epoch: 069; Loss: 0.001505; Accuracy: 98.1509; Val Loss: 0.013015; Val Acc: 76.9042; Elapsed time: 68.3166
# Epoch: 070; Loss: 0.001468; Accuracy: 98.1994; Val Loss: 0.013107; Val Acc: 76.8646; Elapsed time: 62.5680
# Epoch: 071; Loss: 0.001478; Accuracy: 98.0948; Val Loss: 0.012891; Val Acc: 77.0546; Elapsed time: 64.7427
# Epoch: 072; Loss: 0.001441; Accuracy: 98.2198; Val Loss: 0.013130; Val Acc: 76.6112; Elapsed time: 67.3889
# Epoch: 073; Loss: 0.001418; Accuracy: 98.1815; Val Loss: 0.012853; Val Acc: 77.4743; Elapsed time: 68.8271
# Epoch: 074; Loss: 0.001411; Accuracy: 98.2096; Val Loss: 0.012979; Val Acc: 77.2051; Elapsed time: 67.3891
# Epoch: 075; Loss: 0.001382; Accuracy: 98.2810; Val Loss: 0.012732; Val Acc: 77.7355; Elapsed time: 61.8106
# Epoch: 076; Loss: 0.001356; Accuracy: 98.2785; Val Loss: 0.012651; Val Acc: 77.5059; Elapsed time: 67.7395
# Epoch: 077; Loss: 0.001352; Accuracy: 98.2530; Val Loss: 0.012774; Val Acc: 77.7435; Elapsed time: 63.4925
# Epoch: 078; Loss: 0.001328; Accuracy: 98.3269; Val Loss: 0.012636; Val Acc: 77.9731; Elapsed time: 67.7759
# Epoch: 079; Loss: 0.001321; Accuracy: 98.3448; Val Loss: 0.012476; Val Acc: 78.3531; Elapsed time: 63.2663
# Epoch: 080; Loss: 0.001295; Accuracy: 98.3346; Val Loss: 0.012546; Val Acc: 77.7514; Elapsed time: 69.3840
# Epoch: 081; Loss: 0.001269; Accuracy: 98.4187; Val Loss: 0.012413; Val Acc: 78.0285; Elapsed time: 63.2442
# Epoch: 082; Loss: 0.001261; Accuracy: 98.4289; Val Loss: 0.012247; Val Acc: 79.0657; Elapsed time: 68.9874
# Epoch: 083; Loss: 0.001257; Accuracy: 98.4187; Val Loss: 0.012321; Val Acc: 78.5669; Elapsed time: 68.3183
# Epoch: 084; Loss: 0.001244; Accuracy: 98.4315; Val Loss: 0.012034; Val Acc: 79.3032; Elapsed time: 62.6163
# Epoch: 085; Loss: 0.001231; Accuracy: 98.4748; Val Loss: 0.012218; Val Acc: 78.5986; Elapsed time: 69.2718
# Epoch: 086; Loss: 0.001227; Accuracy: 98.4391; Val Loss: 0.012158; Val Acc: 78.9470; Elapsed time: 68.6808
# Epoch: 087; Loss: 0.001181; Accuracy: 98.5514; Val Loss: 0.012236; Val Acc: 78.7648; Elapsed time: 68.8096
# Epoch: 088; Loss: 0.001176; Accuracy: 98.5029; Val Loss: 0.012020; Val Acc: 79.1291; Elapsed time: 67.8252
# Epoch: 089; Loss: 0.001173; Accuracy: 98.5208; Val Loss: 0.011954; Val Acc: 79.2241; Elapsed time: 68.8443
# Epoch: 090; Loss: 0.001131; Accuracy: 98.5922; Val Loss: 0.011929; Val Acc: 79.3745; Elapsed time: 63.1974
# Epoch: 091; Loss: 0.001155; Accuracy: 98.5360; Val Loss: 0.011929; Val Acc: 79.3587; Elapsed time: 68.9179
# Epoch: 092; Loss: 0.001137; Accuracy: 98.5539; Val Loss: 0.011985; Val Acc: 79.3983; Elapsed time: 68.3072
# Epoch: 093; Loss: 0.001123; Accuracy: 98.5896; Val Loss: 0.011739; Val Acc: 79.8654; Elapsed time: 62.8941
# Epoch: 094; Loss: 0.001127; Accuracy: 98.5667; Val Loss: 0.011791; Val Acc: 79.6991; Elapsed time: 66.7199
# Epoch: 095; Loss: 0.001107; Accuracy: 98.5641; Val Loss: 0.011784; Val Acc: 79.4378; Elapsed time: 64.5839
# Epoch: 096; Loss: 0.001101; Accuracy: 98.6381; Val Loss: 0.011959; Val Acc: 79.5408; Elapsed time: 69.3294
# ==> Learning rate updated:  0.001  ->  0.0001
# Epoch: 097; Loss: 0.001077; Accuracy: 98.6661; Val Loss: 0.011880; Val Acc: 79.3983; Elapsed time: 62.1845
# Epoch: 098; Loss: 0.001946; Accuracy: 96.9242; Val Loss: 0.011061; Val Acc: 81.0926; Elapsed time: 69.8277
# Epoch: 099; Loss: 0.001806; Accuracy: 97.2328; Val Loss: 0.011055; Val Acc: 81.2114; Elapsed time: 68.8558
# Epoch: 100; Loss: 0.001728; Accuracy: 97.5031; Val Loss: 0.010914; Val Acc: 81.3223; Elapsed time: 63.7079
# Epoch: 101; Loss: 0.001704; Accuracy: 97.4904; Val Loss: 0.010814; Val Acc: 81.8369; Elapsed time: 69.3303
# Epoch: 102; Loss: 0.001674; Accuracy: 97.5337; Val Loss: 0.010924; Val Acc: 81.7894; Elapsed time: 68.5499
# Epoch: 103; Loss: 0.001675; Accuracy: 97.4827; Val Loss: 0.010932; Val Acc: 81.8052; Elapsed time: 62.3431
# Epoch: 104; Loss: 0.001640; Accuracy: 97.6000; Val Loss: 0.010851; Val Acc: 81.8290; Elapsed time: 69.4379
# ==> Learning rate updated:  0.0001  ->  1e-05
# Epoch: 105; Loss: 0.001623; Accuracy: 97.6383; Val Loss: 0.010920; Val Acc: 82.1378; Elapsed time: 66.9422
# Epoch: 106; Loss: 0.001765; Accuracy: 97.2302; Val Loss: 0.010907; Val Acc: 81.4648; Elapsed time: 64.8374
# Epoch: 107; Loss: 0.001749; Accuracy: 97.2965; Val Loss: 0.010918; Val Acc: 81.6231; Elapsed time: 68.5216
# Epoch: 108; Loss: 0.001725; Accuracy: 97.3093; Val Loss: 0.011164; Val Acc: 81.0135; Elapsed time: 62.4952
# ==> Learning rate updated:  1e-05  ->  1.0000000000000002e-06
# Epoch: 109; Loss: 0.001706; Accuracy: 97.4139; Val Loss: 0.011211; Val Acc: 81.0293; Elapsed time: 68.5338
# Epoch: 110; Loss: 0.001667; Accuracy: 97.4343; Val Loss: 0.010980; Val Acc: 81.6390; Elapsed time: 68.7537
# Epoch: 111; Loss: 0.001701; Accuracy: 97.3220; Val Loss: 0.011123; Val Acc: 81.4093; Elapsed time: 67.7030
# Early stopping!
# Finished Training

# %%
vcpi_util.show_histories([history], ['yep'], 'val_acc')

# %% [markdown]
# ### Test Model

# %%
evaluate(model, test_loader)
# Out:
# 0.8094220161437988

# %%
build_confusion_matrix(model, test_loader)

# %%
preds = []
ground_truth = []

for images, targets in test_loader:

    logits = model(images.to(device))
    preds_aux = [np.argmax(x) for x in logits.cpu().detach().numpy()]
    preds.extend(preds_aux)
    ground_truth.extend(targets.numpy())

vcpi_util.show_confusion_matrix(ground_truth, preds, 43)

# %%
target_list = []

for images, targets in train_loader:

    target_list.extend(targets)

vcpi_util.show_histogram(target_list, train_set.classes)
# Out:
# Counter({2: 2250, 1: 2220, 13: 2160, 12: 2100, 38: 2070, 10: 2010, 4: 1980, 5: 1860, 25: 1500, 9: 1470, 7: 1440, 3: 1410, 8: 1410, 11: 1320, 18: 1200, 35: 1200, 17: 1110, 14: 780, 31: 780, 33: 689, 15: 630, 26: 600, 28: 540, 23: 510, 30: 450, 6: 420, 16: 420, 34: 420, 22: 390, 36: 390, 20: 360, 40: 360, 21: 330, 39: 300, 24: 270, 29: 270, 27: 240, 32: 240, 41: 240, 42: 240, 0: 210, 19: 210, 37: 210})

# %%
#Evaluate without transformatios on test

test_transform = v2.Compose([
        v2.ToImage(),
        v2.Resize((IMG_SIZE, IMG_SIZE)),   
        v2.ToDtype(torch.float32, scale=True),
])

test_set = torchvision.datasets.ImageFolder(root=PATH_TEST_SET, transform = test_transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size = BATCH_SIZE)

evaluate(model, test_loader)
# Out:
# 0.7984956502914429

# %%
#Load the models and change the tests transformations here:

retrieved = torch.load(f'models/model_2.pt')

model.load_state_dict(retrieved['model'])
model.to(device)

optimizer.load_state_dict(retrieved['optimizer'])

test_transform = v2.Compose([
        v2.Resize((IMG_SIZE + 6, IMG_SIZE + 6)),
        v2.CenterCrop(size=(IMG_SIZE, IMG_SIZE)),
        #v2.ToTensor(),
        v2.ToImage(),
        #v2.Grayscale(num_output_channels=3),
        #v2.AutoAugment(),
        #v2.ColorJitter(brightness=0.1, contrast=0.2, saturation=0.2),
        v2.ToDtype(torch.float32, scale=True),
        #v2.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

test_set = torchvision.datasets.ImageFolder(root=PATH_TEST_SET, transform = test_transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size = BATCH_SIZE)

evaluate(model, test_loader)
# Out:
# 0.7874109148979187
